# %% [markdown]
# *Nama:* Muhammad Sir Kafi El Migwar
# <br>*NIM:* 250401020081
# <br>*Kelas:* IF405

# %%
print("Hello, Data Science!")

nama = "Muhammad Sir Kafi El Migwar"
angkatan = 2025
ipk = 3.73
prodi = "PJJ Informatika"
aktif = True

print("Nama:", nama)
print("Angkatan:", angkatan)
print("IPK:", ipk)
print("Program Studi:", prodi)
print("Mahasiswa Aktif:", aktif)

tools = ["Python", "Jupyter Notebook", "Google Colab", "Pandas", "NumPy"]

print("\nTools yang digunakan dalam Data Science:")
for tool in tools:
    print("-", tool)

def perkenalan(nama, prodi, angkatan):
    return f"Halo, saya {nama} dari program studi {prodi}, angkatan {angkatan}"

print("\n" + perkenalan(nama, prodi, angkatan))

# %% [markdown]
# ## Kesimpulan
#
# Pada pertemuan ini saya mempelajari dasar-dasar Python yang digunakan dalam Data Science, termasuk penggunaan variabel, tipe data, list, perulangan, dan fungsi sederhana. Saya juga memahami cara menjalankan program Python menggunakan Jupyter Notebook atau Google Colab.
#
# **Temuan utama:**
# - Python memiliki sintaks yang sederhana dan mudah dipahami untuk pengolahan data.
# - Berbagai tipe data seperti string, integer, float, dan boolean dapat digunakan untuk menyimpan informasi yang berbeda.
# - Fungsi dan perulangan membantu membuat kode lebih terstruktur dan efisien.
#
# **Keterbatasan / Pertanyaan:**
# - Materi masih berfokus pada dasar pemrograman dan belum mencakup pengolahan data yang lebih kompleks.
# - Perlu mempelajari lebih lanjut bagaimana Python digunakan untuk analisis data menggunakan pustaka seperti Pandas dan NumPy.
