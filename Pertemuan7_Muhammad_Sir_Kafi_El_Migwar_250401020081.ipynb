# %% [markdown]
# **Nama:** Muhammad Sir Kafi El Migwar
# <br>**NIM:** 250401020081
# <br>**Kelas:** IF405

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression

from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    r2_score
)

# %%
np.random.seed(42)

n = 300

pengalaman = np.random.uniform(0, 20, n)

edu = np.random.choice(
    [0, 1, 2],
    n
)

kota = np.random.choice(
    ['Jakarta', 'Surabaya', 'Bandung'],
    n
)

gaji = (
    3.0
    + 2.2 * pengalaman
    + 1.5 * edu
    + np.where(kota == 'Jakarta', 4.0, 0)
    + np.random.normal(0, 2, n)
)

df = pd.DataFrame({
    'pengalaman': pengalaman,
    'edu': edu,
    'kota': kota,
    'gaji': gaji
})

print("=== Shape Dataset ===")
print(df.shape)

print("\n=== Data Teratas ===")
print(df.head())

# %%
print("\n=== Statistik Deskriptif ===")
print(df.describe().round(2))

print("\n=== Jumlah Data per Kota ===")
print(df['kota'].value_counts())

# %%
plt.figure(figsize=(8,5))

sns.scatterplot(
    data=df,
    x='pengalaman',
    y='gaji',
    hue='kota',
    palette='Set2',
    alpha=0.7
)

plt.title('Pengalaman vs Gaji per Kota')
plt.show()

# %% [markdown]
# ## Ringkasan Pembelajaran Regresi Linear
#
# Dari tugas ini, saya memperoleh beberapa pemahaman penting, di antaranya:
#
# *   **Pembuatan Dataset**: Menyusun dan meninjau data awal untuk mengenali pola serta karakteristik yang dimiliki.
# *   **Persiapan Data**: Melakukan tahap preprocessing seperti One-Hot Encoding dan StandardScaler, serta membagi data menjadi data latih dan data uji.
# *   **Pelatihan Model**: Menerapkan LinearRegression untuk membangun model dan mempelajari pengaruh masing-masing fitur melalui koefisiennya.
# *   **Evaluasi Model**: Menilai kinerja model menggunakan metrik seperti MAE, RMSE, dan R².
# *   **Visualisasi Hasil**: Membuat grafik Actual vs Predicted serta Residual Plot untuk membantu memahami performa dan kesalahan model secara lebih intuitif.
